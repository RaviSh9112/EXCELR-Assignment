# %%
# Importig Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.preprocessing import StandardScaler

from sklearn import svm
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report


from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split, cross_val_score

# %%
# Loading data
train = pd.read_csv(r"C:\Users\ravindra sharma\Downloads\SalaryData_Train.csv")
test = pd.read_csv(r"C:\Users\ravindra sharma\Downloads\SalaryData_Test.csv")

# %% [markdown]
# # EDA & Data Preprocessing

# %%
train.shape
# Out:
# (11649, 14)

# %%
test.shape
# Out:
# (15060, 14)

# %%
train.head()
# Out:
#    age          workclass   education  educationno        maritalstatus  \
# 0   39          State-gov   Bachelors           13        Never-married
# 1   50   Self-emp-not-inc   Bachelors           13   Married-civ-spouse
# 2   38            Private     HS-grad            9             Divorced
# 3   53            Private        11th            7   Married-civ-spouse
# 4   28            Private   Bachelors           13   Married-civ-spouse
#
#            occupation    relationship    race      sex  capitalgain  \
# 0        Adm-clerical   Not-in-family   White     Male         2174
# 1     Exec-managerial         Husband   White     Male            0
# 2   Handlers-cleaners   Not-in-family   White     Male            0
# 3   Handlers-cleaners         Husband   Black     Male            0
# 4      Prof-specialty            Wife   Black   Female            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# 1            0            13   United-States   <=50K
# 2            0            40   United-States   <=50K
# 3            0            40   United-States   <=50K
# 4            0            40            Cuba   <=50K

# %%
test.head()
# Out:
#    age   workclass      education  educationno        maritalstatus  \
# 0   25     Private           11th            7        Never-married
# 1   38     Private        HS-grad            9   Married-civ-spouse
# 2   28   Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3   44     Private   Some-college           10   Married-civ-spouse
# 4   34     Private           10th            6        Never-married
#
#            occupation    relationship    race    sex  capitalgain  \
# 0   Machine-op-inspct       Own-child   Black   Male            0
# 1     Farming-fishing         Husband   White   Male            0
# 2     Protective-serv         Husband   White   Male            0
# 3   Machine-op-inspct         Husband   Black   Male         7688
# 4       Other-service   Not-in-family   White   Male            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# 1            0            50   United-States   <=50K
# 2            0            40   United-States    >50K
# 3            0            40   United-States    >50K
# 4            0            30   United-States   <=50K

# %%
# Checking for null values
train.isna().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           1
# dtype: int64

# %%
# Checking for null values
test.isna().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
train.dtypes
# Out:
# age               int64
# workclass        object
# education        object
# educationno       int64
# maritalstatus    object
# occupation       object
# relationship     object
# race             object
# sex              object
# capitalgain       int64
# capitalloss       int64
# hoursperweek      int64
# native           object
# Salary           object
# dtype: object

# %%
test.dtypes
# Out:
# age               int64
# workclass        object
# education        object
# educationno       int64
# maritalstatus    object
# occupation       object
# relationship     object
# race             object
# sex              object
# capitalgain       int64
# capitalloss       int64
# hoursperweek      int64
# native           object
# Salary           object
# dtype: object

# %%
# frequency for categorical fields 
category_col =['workclass', 'education','maritalstatus', 'occupation', 'relationship', 'race', 'sex', 'native', 'Salary'] 
for c in category_col:
    print (c)
    print (train[c].value_counts())
    print('\n')
# Out:
# workclass
#  Private             8599
#  Self-emp-not-inc     969
#  Local-gov            792
#  State-gov            520
#  Self-emp-inc         416
#  Federal-gov          351
#  Without-pay            2
# Name: workclass, dtype: int64
#
#
# education
#  HS-grad         3851
#  Some-college    2630
#  Bachelors       1940
#  Masters          636
#  Assoc-voc        480
#  11th             399
#  Assoc-acdm       369
#  10th             323
#  7th-8th          220
#  Prof-school      202
#  9th              171
#  Doctorate        133
#  12th             120
#  5th-6th          106
#  1st-4th           54
#  Preschool         15
# Name: education, dtype: int64
#
#
# maritalstatus
#  Married-civ-spouse       5437
#  Never-married            3729
#  Divorced                 1651
#  Separated                 374
#  Widowed                   300
#  Married-spouse-absent     150
#  Married-AF-spouse           8
# Name: maritalstatus, dtype: int64
#
#
# occupation
#  Prof-specialty       1541
#  Craft-repair         1537
#  Exec-managerial      1510
#  Adm-clerical         1484
#  Sales                1406
#  Other-service        1264
#  Machine-op-inspct     758
#  Transport-moving      618
#  Handlers-cleaners     502
#  Farming-fishing       370
#  Tech-support          344
#  Protective-serv       258
#  Priv-house-serv        55
#  Armed-Forces            2
# Name: occupation, dtype: int64
#
#
# relationship
#  Husband           4795
#  Not-in-family     3015
#  Own-child         1703
#  Unmarried         1236
#  Wife               570
#  Other-relative     330
# Name: relationship, dtype: int64
#
#
# race
#  White                 10024
#  Black                  1102
#  Asian-Pac-Islander      335
#  Amer-Indian-Eskimo      106
#  Other                    82
# Name: race, dtype: int64
#
#
# sex
#  Male      7891
#  Female    3758
# Name: sex, dtype: int64
#
#
# native
#  United-States                 10606
#  Mexico                          229
#  Philippines                      67
#  Puerto-Rico                      53
#  Germany                          53
#  Canada                           48
#  El-Salvador                      37
#  India                            36
#  Cuba                             36
#  Jamaica                          35
#  England                          34
#  South                            31
#  China                            31
#  Dominican-Republic               26
#  Italy                            26
#  Vietnam                          26
#  Poland                           25
#  Guatemala                        24
#  Iran                             22
#  Japan                            21
#  Taiwan                           19
#  Haiti                            19
#  Greece                           18
#  Columbia                         14
#  Portugal                         13
#  Nicaragua                        11
#  Ireland                          11
#  Ecuador                          10
#  Peru                             10
#  Cambodia                          9
#  Thailand                          8
#  France                            7
#  Trinadad&Tobago                   6
#  Yugoslavia                        5
#  Honduras                          5
#  Laos                              4
#  Outlying-US(Guam-USVI-etc)        4
#  Hong                              4
#  Scotland                          3
#  Hungary                           2
#  United-S                          1
# Name: native, dtype: int64
#
#
# Salary
#  <=50K    8772
#  >50K     2876
# Name: Salary, dtype: int64

# %%
# countplot for all categorical columns
import seaborn as sns
sns.set(rc={'figure.figsize':(15,8)})
cat_col = ['workclass', 'education','maritalstatus', 'occupation', 'relationship', 'race', 'sex','Salary']
for col in cat_col:
    plt.figure() #this creates a new figure on which your plot will appear
    sns.countplot(x = col, data = train, palette = 'Set3');

# %%
# printing unique values from each categoricla columns

print('workclass',train.workclass.unique())
print('education',train.education.unique())
print('maritalstatus',train['maritalstatus'].unique())
print('occupation',train.occupation.unique())
print('relationship',train.relationship.unique())
print('race',train.race.unique())
print('sex',train.sex.unique())
print('native',train['native'].unique())
print('Salary',train.Salary.unique())
# Out:
# workclass [' State-gov' ' Self-emp-not-inc' ' Private' ' Federal-gov' ' Local-gov'
#  ' Self-emp-inc' ' Without-pay']
# education [' Bachelors' ' HS-grad' ' 11th' ' Masters' ' 9th' ' Some-college'
#  ' Assoc-acdm' ' 7th-8th' ' Doctorate' ' Assoc-voc' ' Prof-school'
#  ' 5th-6th' ' 10th' ' Preschool' ' 12th' ' 1st-4th']
# maritalstatus [' Never-married' ' Married-civ-spouse' ' Divorced'
#  ' Married-spouse-absent' ' Separated' ' Married-AF-spouse' ' Widowed']
# occupation [' Adm-clerical' ' Exec-managerial' ' Handlers-cleaners' ' Prof-specialty'
#  ' Other-service' ' Sales' ' Transport-moving' ' Farming-fishing'
#  ' Machine-op-inspct' ' Tech-support' ' Craft-repair' ' Protective-serv'
#  ' Armed-Forces' ' Priv-house-serv']
# relationship [' Not-in-family' ' Husband' ' Wife' ' Own-child' ' Unmarried'
#  ' Other-relative']
# race [' White' ' Black' ' Asian-Pac-Islander' ' Amer-Indian-Eskimo' ' Other']
# sex [' Male' ' Female']
# native [' United-States' ' Cuba' ' Jamaica' ' India' ' Mexico' ' Puerto-Rico'
#  ' Honduras' ' England' ' Canada' ' Germany' ' Iran' ' Philippines'
#  ' Poland' ' Columbia' ' Cambodia' ' Thailand' ' Ecuador' ' Laos'
#  ' Taiwan' ' Haiti' ' Portugal' ' Dominican-Republic' ' El-Salvador'
#  ' France' ' Guatemala' ' Italy' ' China' ' South' ' Japan' ' Yugoslavia'
#  ' Peru' ' Outlying-US(Guam-USVI-etc)' ' Scotland' ' Trinadad&Tobago'
#  ' Greece' ' Nicaragua' ' Vietnam' ' Hong' ' Ireland' ' Hungary'
#  ' United-S']
# Salary [' <=50K' ' >50K' nan]

# %%
train[['Salary', 'age']].groupby(['Salary'], as_index=False).mean().sort_values(by='age', ascending=False)
# Out:
#    Salary        age
# 1    >50K  43.642907
# 0   <=50K  36.606817

# %%
plt.style.use('seaborn-whitegrid')
x, y, hue = "race", "prop", "sex"
#hue_order = ["Male", "Female"]
plt.figure(figsize=(20,5)) 
f, axes = plt.subplots(1, 2)
sns.countplot(x=x, hue=hue, data=train, ax=axes[0])

prop_df = (train[x]
           .groupby(train[hue])
           .value_counts(normalize=True)
           .rename(y)
           .reset_index())

sns.barplot(x=x, y=y, hue=hue, data=prop_df, ax=axes[1])
# Out:
# C:\Users\ravindra sharma\AppData\Local\Temp\ipykernel_8136\3320154224.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')
# <AxesSubplot: xlabel='race', ylabel='prop'>

# %%
g = sns.jointplot(x = 'age', 
              y = 'hoursperweek',
              data = train, 
              kind = 'hex', 
              cmap= 'hot', 
              size=10)

#http://stackoverflow.com/questions/33288830/how-to-plot-regression-line-on-hexbins-with-seaborn
sns.regplot(train.age, train['hoursperweek'], ax=g.ax_joint, scatter=False, color='yellow')
# Out:
# C:\Users\ravindra sharma\anaconda3\lib\site-packages\seaborn\axisgrid.py:2182: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\ravindra sharma\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot: xlabel='age', ylabel='hoursperweek'>

# %% [markdown]
# # Feature encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
train = train.apply(LabelEncoder().fit_transform)
train.head()
# Out:
#    age  workclass  education  educationno  maritalstatus  occupation  \
# 0   22          5          9           12              4           0
# 1   33          4          9           12              2           3
# 2   21          2         11            8              0           5
# 3   36          2          1            6              2           5
# 4   11          2          9           12              2           9
#
#    relationship  race  sex  capitalgain  capitalloss  hoursperweek  native  \
# 0             1     4    1           18            0            39      38
# 1             0     4    1            0            0            12      38
# 2             1     4    1            0            0            39      38
# 3             0     2    1            0            0            39      38
# 4             5     2    0            0            0            39       4
#
#    Salary
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
test = test.apply(LabelEncoder().fit_transform)
test.head()
# Out:
#    age  workclass  education  educationno  maritalstatus  occupation  \
# 0    8          2          1            6              4           6
# 1   21          2         11            8              2           4
# 2   11          1          7           11              2          10
# 3   27          2         15            9              2           6
# 4   17          2          0            5              4           7
#
#    relationship  race  sex  capitalgain  capitalloss  hoursperweek  native  \
# 0             3     2    1            0            0            39      37
# 1             0     4    1            0            0            49      37
# 2             0     4    1            0            0            39      37
# 3             0     2    1           87            0            39      37
# 4             1     4    1            0            0            29      37
#
#    Salary
# 0       0
# 1       0
# 2       1
# 3       1
# 4       0

# %% [markdown]
# # Test-Train-Split

# %%
drop_elements = ['education', 'native', 'Salary']
X = train.drop(drop_elements, axis=1)

# %%
y = train['Salary']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# # Building Multinomial Naive Bays Model

# %%
# Preparing a naive bayes model on training data set 

from sklearn.naive_bayes import MultinomialNB as MB
from sklearn.naive_bayes import GaussianNB as GB

# Multinomial Naive Bayes
classifier_mb = MB()
classifier_mb.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
score_multinomial = classifier_mb.score(X_test,y_test)
print('The accuracy of Gaussian Naive Bayes is', score_multinomial)
# Out:
# The accuracy of Gaussian Naive Bayes is 0.7812743823146944

# %%
from sklearn import metrics

drop_elements = ['education', 'native', 'Salary']
X_new = test.drop(drop_elements, axis=1)

y_new = test['Salary']

# %%
# make predictions
new_prediction = classifier_mb.predict(X_new)
# summarize the fit of the model
print(metrics.classification_report(y_new, new_prediction))
print(metrics.confusion_matrix(y_new, new_prediction))

print("Accuracy:",metrics.accuracy_score(y_new, new_prediction))
print("Precision:",metrics.precision_score(y_new, new_prediction))
print("Recall:",metrics.recall_score(y_new, new_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.94      0.87     11360
#            1       0.61      0.31      0.41      3700
#
#     accuracy                           0.78     15060
#    macro avg       0.71      0.62      0.64     15060
# weighted avg       0.76      0.78      0.75     15060
#
# [[10623   737]
#  [ 2569  1131]]
# Accuracy: 0.7804780876494024
# Precision: 0.6054603854389722
# Recall: 0.30567567567567566

# %% [markdown]
# # Building Gaussian Naive Bays Model

# %%
# Gaussian Naive Bayes
classifier_gb = GB()
classifier_gb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
score_gaussian = classifier_gb.score(X_test,y_test)
print('The accuracy of Gaussian Naive Bayes is', score_gaussian)
# Out:
# The accuracy of Gaussian Naive Bayes is 0.8135240572171651

# %% [markdown]
# ## Testing Gaussian Naive Bays model on SalaryData_Test.csv

# %%
# make predictions
new_prediction = classifier_gb.predict(X_new)
# summarize the fit of the model
print(metrics.classification_report(y_new, new_prediction))
print(metrics.confusion_matrix(y_new, new_prediction))

print("Accuracy:",metrics.accuracy_score(y_new, new_prediction))
print("Precision:",metrics.precision_score(y_new, new_prediction))
print("Recall:",metrics.recall_score(y_new, new_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.93      0.88     11360
#            1       0.67      0.47      0.55      3700
#
#     accuracy                           0.81     15060
#    macro avg       0.76      0.70      0.72     15060
# weighted avg       0.80      0.81      0.80     15060
#
# [[10520   840]
#  [ 1965  1735]]
# Accuracy: 0.8137450199203188
# Precision: 0.6737864077669903
# Recall: 0.4689189189189189
